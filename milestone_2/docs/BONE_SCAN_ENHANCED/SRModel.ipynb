# %%
import os
import urllib.request

# Create a folder for models
model_path = "SuperResolution"
#os.makedirs(model_path, exist_ok=True)

# URL for the EDSR model (x4 upscale)
url = "https://github.com/Saafke/EDSR_Tensorflow/raw/master/models/EDSR_x4.pb"
save_path = os.path.join(model_path, "EDSR_x4.pb")

print("Downloading Super Resolution Model (EDSR_x4)...")
try:
    urllib.request.urlretrieve(url, save_path)
    print(f"Success! Model saved to: {save_path}")
except Exception as e:
    print(f"Error downloading: {e}")
# Out:
# Downloading Super Resolution Model (EDSR_x4)...
# Success! Model saved to: SuperResolution/EDSR_x4.pb
